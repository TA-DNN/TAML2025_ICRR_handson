# %% [markdown]
# # DST Parser Exercises
#
# This notebook contains hands-on exercises for learning the `dstparser` package. Work through each task using the hints provided.
#
# ## Overview
#
# You'll practice:
# 1. **Structured format parsing** (`parse_dst_file`)
# 2. **Variable-length format parsing** (`parse_dst_file_vlen`)
# 3. **TAx4 file handling** (`parse_dst_file_tax4`)
# 4. **Working with multiple files and HDF5**
#
# **Tip**: Refer to `00_complete_dstparser_tutorial.ipynb` if you get stuck!

# %% [markdown]
# ## Setup
#
# **Task**: Import necessary libraries
#
# **Hint**: You'll need:
# - `numpy` for array operations
# - `matplotlib.pyplot` for plotting
# - `Path` from `pathlib` for file paths
# - `parse_dst_file`, `parse_dst_file_vlen` from `dstparser`
# - `print_data_info` from `dstparser.read_data`
# - `XmaxReader` from `dstparser.xmax_reader`

# %%
# Your code here
# %load_ext autoreload
# %autoreload 2

# Import libraries

# %% [markdown]
# ## Part 1: Structured Format Exercises
#
# ### Exercise 1.1: Basic Parsing
#
# **Task**: Parse a DST file and print basic information
#
# **Hints**:
# 1. Use `Path` to create the file path: `dst_dir / "DAT005020_gea.rufldf.dst.gz"`
# 2. Call `parse_dst_file(dst_file)` to parse
# 3. Print the number of events using `len(data['energy'])`
# 4. Use `print_data_info(data)` to see all fields

# %%
# Set up file path
dst_dir = "/ceph/work/SATORI/projects/TA-ASIoP/tasdmc_dstbank/qgsii04proton/080417_160603/Em1_bsdinfo"
dst_file = # Your code here

# Parse the file
data = # Your code here

# Print information

# %% [markdown]
# ### Exercise 1.2: Explore Field Shapes
#
# **Task**: Loop through all fields and print their shapes and data types
#
# **Hint**: Use a for loop over `data.keys()` and print `key`, `data[key].shape`, and `data[key].dtype`

# %%
# Your code here

# %% [markdown]
# ### Exercise 1.3: Parse with Custom Options
#
# **Task**: Parse the file WITHOUT standard reconstruction but WITH shower parameters
#
# **Hints**:
# 1. Set `add_standard_recon=False`
# 2. Set `add_shower_params=True`
# 3. Try using `ntile=11` for an 11×11 grid instead of 7×7

# %%
# Your code here
data_custom = parse_dst_file(
    # Fill in parameters
)

# Print available fields

# %% [markdown]
# ### Exercise 1.4: Separate Upper/Lower PMT Traces
#
# **Task**: Parse with separate upper and lower PMT time traces
#
# **Hint**: Set `avg_traces=False` to keep `time_traces_low` and `time_traces_up` separate

# %%
# Your code here

# %% [markdown]
# ### Exercise 1.5: Adding Xmax Information
#
# **Task**: Parse the file with Xmax data from QGSJetII-04 model
#
# **Hints**:
# 1. Create an `XmaxReader` with `data_dir=dst_dir` and `model="QGSJetII-04"`
# 2. Pass it to `parse_dst_file` via the `xmax_reader` parameter
# 3. Check that the `xmax` field exists in the output

# %%
# Create XmaxReader
xmax_reader = # Your code here

# Parse with xmax
data_with_xmax = # Your code here

# Print xmax statistics

# %% [markdown]
# ### Exercise 1.6: Compare Hadronic Models
#
# **Task**: Load data with both QGSJetII-04 and EPOS-LHC models and compare their Xmax interpolations
#
# **Hints**:
# 1. Parse twice with different `XmaxReader` instances (different `model` parameter)
# 2. Create a scatter plot with energy on x-axis and xmax on y-axis
# 3. Use different colors for each model

# %%
# Parse with QGSJetII-04

# Parse with EPOS-LHC

# Create comparison plot

# %% [markdown]
# ### Exercise 1.7: Visualize Detector Positions
#
# **Task**: Create a 2D plot showing detector positions and shower cores
#
# **Hints**:
# 1. Plot `detector_positions[..., 0]` vs `detector_positions[..., 1]` (transformed coordinates)
# 2. Overlay `shower_core[:, 0]` vs `shower_core[:, 1]` (MC truth) as stars
# 3. Overlay `std_recon_shower_core` positions as crosses
# 4. Use `plt.gca().set_aspect("equal")` for proper aspect ratio

# %%
# Parse with all data
data = parse_dst_file(dst_file)

# Create plot

# %% [markdown]
# ### Exercise 1.8: Access Single Event Data
#
# **Task**: Extract and analyze data for event index 0
#
# **Hints**:
# 1. Get signals: `data['total_signals'][event_idx]`
# 2. Find active detectors: `signals > 0`
# 3. Count them: `np.sum(active)`
# 4. Print energy, zenith angle (use `angular_dist` from `dstparser.std_qcuts`), and signal range

# %%
from dstparser.std_qcuts import angular_dist

event_idx = 0

# Your code here

# %% [markdown]
# ### Exercise 1.9: Apply Quality Cuts
#
# **Task**: Apply standard spectrum quality cuts and filter the data
#
# **Hints**:
# 1. Import `std_spectrum_quality_cuts` from `dstparser.std_qcuts`
# 2. Get the mask: `qcut_mask = std_spectrum_quality_cuts(data)`
# 3. Filter: `{key: data[key][qcut_mask] for key in data}`
# 4. Print number of events before and after

# %%
# Your code here

# %% [markdown]
# ## Part 2: Variable-Length Format Exercises
#
# ### Exercise 2.1: Basic Variable-Length Parsing
#
# **Task**: Parse a file in variable-length format and explore the structure
#
# **Hints**:
# 1. Use `parse_dst_file_vlen(dst_file)`
# 2. Use `print_data_info(data_vlen)` to see fields
# 3. Note the presence of `hit_offsets` and `hit_tt_offsets`

# %%
# Your code here

# %% [markdown]
# ### Exercise 2.2: Understand the Offset System
#
# **Task**: Calculate and print statistics about the offset structure
#
# **Hints**:
# 1. Number of events: `len(data_vlen['hit_offsets']) - 1`
# 2. Total hits: `data_vlen['hit_offsets'][-1]`
# 3. Total windows: `data_vlen['hit_tt_offsets'][-1]`
# 4. Calculate averages

# %%
# Your code here

# %% [markdown]
# ### Exercise 2.3: Parse with Minimal Data
#
# **Task**: Parse with only detector readings (no MC truth or std recon)
#
# **Hint**: Set both `add_shower_params=False` and `add_standard_recon=False`

# %%
# Your code here

# %% [markdown]
# ### Exercise 2.4: Access Hit-Level Data for One Event
#
# **Task**: Extract all hit-level data for event index 20
#
# **Hints**:
# 1. Get boundaries: `hits_start = data_vlen["hit_offsets"][evt_idx]`
# 2. `hits_end = data_vlen["hit_offsets"][evt_idx + 1]`
# 3. Slice arrays: `data_vlen["pulse_area"][hits_start:hits_end]`
# 4. Print detector IDs, pulse areas, and number of hits

# %%
evt_idx = 20

# Your code here

# %% [markdown]
# ### Exercise 2.5: Access Time Traces for One Event
#
# **Task**: Extract all time traces for event index 9
#
# **Hints**:
# 1. First get hit boundaries (as in Exercise 2.4)
# 2. Then get time trace boundaries: `tt_start = data_vlen["hit_tt_offsets"][hits_start]`
# 3. `tt_end = data_vlen["hit_tt_offsets"][hits_end]`
# 4. Slice: `data_vlen["time_traces"][tt_start:tt_end]`
# 5. Verify total windows equals sum of nfolds

# %%
evt_idx = 9

# Your code here

# %% [markdown]
# ### Exercise 2.6: Split Time Traces by Hit
#
# **Task**: Split time traces into separate arrays for each hit
#
# **Hints**:
# 1. Get nfolds for the event: `data_vlen["nfold"][hits_start:hits_end]`
# 2. Create split indices: `windows_offsets = np.cumsum([0] + list(nfolds))`
# 3. Split: `np.split(ttrace, windows_offsets[1:-1])`
# 4. Print shape of each hit's traces

# %%
# Continue from Exercise 2.5

# Your code here

# %% [markdown]
# ### Exercise 2.7: Visualize Time Traces
#
# **Task**: Plot time traces for the first 3 hits of an event
#
# **Hints**:
# 1. Use split_ttraces from Exercise 2.6
# 2. For each hit, join windows: `traces.transpose(1, 0, 2).reshape(2, -1)`
# 3. Plot lower (index 0) and upper (index 1) PMT traces
# 4. Use `plt.subplots(1, 3)` for side-by-side plots

# %%
# Your code here

# %% [markdown]
# ### Exercise 2.8: Analyze Hit Distribution
#
# **Task**: Create a histogram showing the distribution of hits per event
#
# **Hints**:
# 1. Calculate event lengths: `event_lens = np.diff(data_vlen["hit_offsets"])`
# 2. Create histogram: `plt.hist(event_lens, bins=30)`
# 3. Add labels and title with mean and max values

# %%
# Your code here

# %% [markdown]
# ### Exercise 2.9: Check Detector Uniqueness
#
# **Task**: Check if any events have duplicate detector IDs
#
# **Hints**:
# 1. Loop over events
# 2. For each event, get detector_ids
# 3. Calculate ratio: `len(np.unique(det_ids)) / len(det_ids)`
# 4. Create histogram of ratios
# 5. Count events with ratio < 1.0

# %%
# Your code here

# %% [markdown]
# ### Exercise 2.10: Visualize Event Footprints
#
# **Task**: Plot detector positions for multiple events on the same figure
#
# **Hints**:
# 1. Loop over events [25, 26, 28, 29, 30, 31]
# 2. Extract positions: `data_vlen["detector_positions"][hits_start:hits_end]`
# 3. Convert to km: `positions * 1200 / 1000`
# 4. Scatter plot x vs y coordinates
# 5. Use `plt.gca().set_aspect("equal")`

# %%
# Your code here

# %% [markdown]
# ## Part 3: Working with Multiple Files
#
# ### Exercise 3.1: Find All DST Files
#
# **Task**: Search for all DST files in the directory using glob pattern
#
# **Hints**:
# 1. Use `Path(dst_dir).rglob("DAT*dst.gz")`
# 2. Convert to list of strings and sort
# 3. Print the number of files found and first 5 filenames

# %%
# Your code here

# %% [markdown]
# ### Exercise 3.2: Accumulate Data from Multiple Files
#
# **Task**: Parse the first 5 files and accumulate all data
#
# **Hints**:
# 1. Create empty dict: `acc_data = dict()`
# 2. Loop over `dst_files[0:5]`
# 3. Parse each file with `parse_dst_file`
# 4. For each key, append to list: `acc_data.setdefault(key, []).append(value)`
# 5. Skip if `data is None`

# %%
# Your code here

# %% [markdown]
# ### Exercise 3.3: Save to HDF5
#
# **Task**: Save accumulated data to HDF5 file
#
# **Hints**:
# 1. Import: `from dstparser.cli.io import save2hdf5, read_h5`
# 2. Import: `from dstparser.read_data import read_hdf5_metadata`
# 3. Call `save2hdf5(acc_data, filename="output.h5", compress_arrs=[])`
# 4. Use `read_hdf5_metadata` to check what was saved
# 5. Check file size with `os.path.getsize`

# %%
import os

output_file = "/ceph/work/SATORI/antonpr/ml/benMC/sdanalysis_2019/handson/handson_new/exercise_output.h5"

# Your code here

# %% [markdown]
# ### Exercise 3.4: Save with Compression
#
# **Task**: Save again with compression on time-related arrays
#
# **Hint**: Pass `compress_arrs=["time", "arrival", "detector"]` to compress arrays containing these substrings

# %%
# Your code here

# %% [markdown]
# ### Exercise 3.5: Read from HDF5
#
# **Task**: Load the HDF5 file back and verify the data
#
# **Hint**: Use `read_h5(output_file)` and `print_data_info`

# %%
# Your code here

# %% [markdown]
# ## Part 4: Variable-Length Format with HDF5
#
# ### Exercise 4.1: Save Variable-Length Data to HDF5
#
# **Task**: Parse multiple files in variable-length format and save incrementally to HDF5
#
# **Hints**:
# 1. Import: `import h5py` and `from dstparser import append_to_hdf5`
# 2. Open file: `with h5py.File(filename, "w") as f:`
# 3. Loop over files and parse with `parse_dst_file_vlen`
# 4. Call `append_to_hdf5(f, data)` for each file
# 5. Use `read_hdf5_metadata` to check the result

# %%
output_file_vlen = "/ceph/work/SATORI/antonpr/ml/benMC/sdanalysis_2019/handson/handson_new/exercise_vlen_output.h5"

# Your code here

# %% [markdown]
# ### Exercise 4.2: Use H5DST Helper Class
#
# **Task**: Open the variable-length HDF5 file with H5DST and list available fields
#
# **Hints**:
# 1. Import: `from dstparser import H5DST`
# 2. Open: `rdata = H5DST(output_file_vlen)`
# 3. List fields: `rdata.keys()`

# %%
# Your code here

# %% [markdown]
# ### Exercise 4.3: Access Event-Level Data from H5DST
#
# **Task**: Access energy array and create a histogram
#
# **Hints**:
# 1. Get energies: `rdata["energy"]` (returns numpy array)
# 2. Create histogram with log scale on y-axis
# 3. Add labels and title

# %%
# Your code here

# %% [markdown]
# ### Exercise 4.4: Two-Level Indexing with H5DST
#
# **Task**: Access time traces for a specific event and hit using H5DST
#
# **Hints**:
# 1. Access all hits for event: `rdata["time_traces"][evt_idx]`
# 2. Access specific hit: `rdata["time_traces"][evt_idx, hit_idx]`
# 3. Print shapes to understand the structure

# %%
evt_idx = 100
hit_idx = 2

# Your code here

# %% [markdown]
# ### Exercise 4.5: Plot Time Traces from HDF5
#
# **Task**: Extract and plot time traces for a specific event and hit
#
# **Hints**:
# 1. Get traces: `rdata["time_traces"][evt_idx, hit_idx]`
# 2. Join windows: `tt.transpose(1, 0, 2).reshape(2, -1)`
# 3. Plot lower and upper PMT traces
# 4. Add labels, legend, and grid

# %%
# Your code here

# %% [markdown]
# ## Part 5: TAx4 File Format (Bonus)
#
# ### Exercise 5.1: Using parse_dst_file_tax4
#
# **Task**: If you have TAx4 files, parse them using `parse_dst_file_tax4`
#
# **Hints**:
# 1. Import: `from dstparser import parse_dst_file_tax4`
# 2. Use exactly the same parameters as `parse_dst_file`
# 3. The output format is identical
# 4. Check that detector positions make sense

# %%
# Example (uncomment if you have TAx4 files):
# from dstparser import parse_dst_file_tax4
# 
# tax4_file = Path("/path/to/tax4/DAT000000_gea.rufldf.dst.gz")
# data_tax4 = parse_dst_file_tax4(tax4_file)
# 
# print(f"Parsed {len(data_tax4['energy'])} TAx4 events")
# print_data_info(data_tax4)

# %% [markdown]
# ## Challenge Exercises
#
# ### Challenge 1: Energy Spectrum
#
# **Task**: Create an energy spectrum plot (dN/dE vs E) for events passing quality cuts
#
# **Hints**:
# 1. Parse multiple files and apply `std_spectrum_quality_cuts`
# 2. Create log-binned histogram of energies
# 3. Normalize by bin width: `counts / np.diff(bins)`
# 4. Use log-log scale

# %%
# Your code here

# %% [markdown]
# ### Challenge 2: Reconstruction Accuracy
#
# **Task**: Compare MC truth energy with reconstructed energy
#
# **Hints**:
# 1. Create scatter plot: true energy vs reconstructed energy
# 2. Plot diagonal line (y=x) for reference
# 3. Calculate resolution: `(recon - true) / true`
# 4. Create histogram of relative differences

# %%
# Your code here

# %% [markdown]
# ### Challenge 3: Signal Lateral Distribution
#
# **Task**: Plot signal vs distance from shower core for all detectors
#
# **Hints**:
# 1. Parse data in variable-length format
# 2. For each event, calculate distance of each hit from shower core
# 3. Plot signal (pulse_area) vs distance
# 4. Use log scale for signal
# 5. Fit with Nishimura-Kamata-Greisen function (optional)

# %%
# Your code here
